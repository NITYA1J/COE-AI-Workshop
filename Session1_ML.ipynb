# %% [markdown]
# <a href="https://colab.research.google.com/github/NITYA1J/COE-AI-Workshop/blob/main/Session1_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 1 Embedded Tool Skill
# ## Loading Data and Identifying Inputs, Target, Units, and Observation
#
# This notebook introduces only the pandas operations needed for Session 1.

# %%
import requests

# URL for a common Iris dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
response = requests.get(url)

# Save the content to a file in /tmp/
file_path = "/tmp/iris.csv"
with open(file_path, "wb") as f:
    f.write(response.content)

print(f"Downloaded iris.csv to {file_path}")
# Out:
# Downloaded iris.csv to /tmp/iris.csv

# %% [markdown]
# The [Iris flower dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set) is a multivariate dataset introduced by the British statistician and biologist Ronald Fisher in 1936. It is sometimes called **Fisher's Iris dataset** or **Anderson's Iris dataset** because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species.

# %%
import pandas as pd

df = pd.read_csv("/tmp/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Inspect the dataset

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
print("\nData types:")
print(df.dtypes)
print("\nMissing values:")
print(df.isna().sum())
# Out:
# Shape: (150, 5)
#
# Columns:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#
# Data types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
# Missing values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Define the problem elements
#
# - Unit of observation: one flower
# - Inputs: petal length and petal width
# - Input units: centimeters
# - Target: species
# - Task: multiclass classification
# - Metric: accuracy

# %%
# Correct the column names based on the DataFrame's actual column names
input_columns = ["petal_length", "petal_width"]
target_column = "species"

X = df[input_columns]
y = df[target_column]

print("Inputs:")
display(X.head())

print("\nTarget:")
display(y.head().to_frame())
# Out:
# Inputs:
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2
# Target:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## Faculty adaptation
#
# Replace the entries below with one example from your discipline.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot of petal length vs. petal width, colored by species
plt.figure(figsize=(8, 6))
sns.scatterplot(x='petal_length', y='petal_width', hue='species', data=df, s=80)
plt.title('Iris Petal Length vs. Petal Width by Species')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend(title='Species')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
my_problem = {
    "Unit of observation": "one flower",
    "Input variables": ["petal length", "petal width"],
    "Input units": ["centimeters"],
    "Target": "species",
    "Model task": "multiclass classification",
    "Metric": "accuracy"
}

my_problem
# Out:
# {'Unit of observation': 'one flower',
#  'Input variables': ['petal length', 'petal width'],
#  'Input units': ['centimeters'],
#  'Target': 'species',
#  'Model task': 'multiclass classification',
#  'Metric': 'accuracy'}
