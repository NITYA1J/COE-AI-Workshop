# %% [markdown]
# <a href="https://colab.research.google.com/github/NITYA1J/COE-AI-Workshop/blob/main/Session3_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 3 Embedded Tool Skill
# ## A Minimal scikit-learn Regression Workflow
#
# Workflow:
# 1. load data;
# 2. define inputs and target;
# 3. split data;
# 4. establish a baseline;
# 5. train;
# 6. predict;
# 7. evaluate.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

df = pd.read_csv("regression_workshop.csv")
df.head()
# Out:
#    temperature_c  pressure_kpa  curing_time_min  material_fraction  \
# 0        203.689       592.492           40.383              0.241
# 1        208.488       634.720           37.377              0.434
# 2        224.510       501.763           44.023              0.260
# 3        225.770       432.842           37.968              0.372
# 4        205.694       506.028           36.975              0.271
#
#    strength_mpa
# 0       173.874
# 1       180.947
# 2       130.553
# 3       127.346
# 4       158.160

# %%
features = [
    "temperature_c",
    "pressure_kpa",
    "curing_time_min",
    "material_fraction"
]
target = "strength_mpa"

X = df[features]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %% [markdown]
# ## Baseline

# %%
baseline_predictions = np.full(len(y_test), y_train.mean())

print("Baseline MAE:",
      round(mean_absolute_error(y_test, baseline_predictions), 3))
# Out:
# Baseline MAE: 14.208

# %% [markdown]
# ## Linear regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Model MAE:", round(mean_absolute_error(y_test, predictions), 3))
print("Model R²:", round(r2_score(y_test, predictions), 3))
# Out:
# Model MAE: 10.293
# Model R²: 0.374

# %% [markdown]
# ## Interpretation activity
#
# - Did the model outperform the baseline?
# - Is the MAE acceptable in MPa?
# - Which input variables are available before prediction?
