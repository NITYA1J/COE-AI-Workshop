# %% [markdown]
# # Session 3 Embedded Tool Skill
# ## A Minimal scikit-learn Regression Workflow
#
# Workflow:
# 1. load data;
# 2. define inputs and target;
# 3. split data;
# 4. establish a baseline;
# 5. train;
# 6. predict;
# 7. evaluate.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

df = pd.read_csv("regression_workshop.csv")
df.head()
# Out:
#    temperature_c  pressure_kpa  curing_time_min  material_fraction  \
# 0        203.689       592.492           40.383              0.241
# 1        208.488       634.720           37.377              0.434
# 2        224.510       501.763           44.023              0.260
# 3        225.770       432.842           37.968              0.372
# 4        205.694       506.028           36.975              0.271
#
#    strength_mpa
# 0       173.874
# 1       180.947
# 2       130.553
# 3       127.346
# 4       158.160

# %%
features = [
    "temperature_c",
    "pressure_kpa",
    "curing_time_min",
    "material_fraction"
]
target = "strength_mpa"

X = df[features]
y = df[target]

# %%
X
# Out:
#      temperature_c  pressure_kpa  curing_time_min  material_fraction
# 0          203.689       592.492           40.383              0.241
# 1          208.488       634.720           37.377              0.434
# 2          224.510       501.763           44.023              0.260
# 3          225.770       432.842           37.968              0.372
# 4          205.694       506.028           36.975              0.271
# ..             ...           ...              ...                ...
# 175        199.665       569.499           47.056              0.320
# 176        200.884       514.050           30.766              0.315
# 177        218.626       464.011           44.648              0.399
# 178        194.594       505.640           39.579              0.363
# 179        180.872       529.775           38.138              0.158
#
# [180 rows x 4 columns]

# %%
y
# Out:
# 0      173.874
# 1      180.947
# 2      130.553
# 3      127.346
# 4      158.160
#         ...
# 175    171.893
# 176    165.764
# 177    159.231
# 178    146.657
# 179    124.481
# Name: strength_mpa, Length: 180, dtype: float64

# %%
X_train
# Out:
#      temperature_c  pressure_kpa  curing_time_min  material_fraction
# 132        202.062       553.301           45.926              0.150
# 90         188.135       515.672           45.118              0.171
# 38         196.485       496.478           36.342              0.338
# 169        219.512       521.751           45.551              0.412
# 115        212.394       561.888           57.057              0.256
# ..             ...           ...              ...                ...
# 71         196.123       508.972           49.581              0.216
# 106        197.465       555.000           53.490              0.305
# 14         193.826       504.820           27.105              0.188
# 92         207.477       417.367           40.820              0.387
# 102        207.964       544.693           46.445              0.356
#
# [135 rows x 4 columns]

# %%
y_train
# Out:
# 132    158.152
# 90     137.673
# 38     142.100
# 169    183.654
# 115    194.558
#         ...
# 71     172.868
# 106    182.239
# 14     128.569
# 92     166.528
# 102    198.736
# Name: strength_mpa, Length: 135, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %% [markdown]
# ## Baseline

# %%
baseline_predictions = np.full(len(y_test), y_train.mean())

print("Baseline MAE:",
      round(mean_absolute_error(y_test, baseline_predictions), 3))
# Out:
# Baseline MAE: 14.208

# %% [markdown]
# ## Linear regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Model MAE:", round(mean_absolute_error(y_test, predictions), 3))
print("Model R²:", round(r2_score(y_test, predictions), 3))
# Out:
# Model MAE: 10.293
# Model R²: 0.374

# %%
model
# Out:
# LinearRegression()

# %% [markdown]
# ## Interpretation activity
#
# - Did the model outperform the baseline? Yes
# - Is the MAE acceptable in MPa? less than 10 to 15
# - Which input variables are available before prediction? Pressure, Curing_time, temperature, material_fraction,
